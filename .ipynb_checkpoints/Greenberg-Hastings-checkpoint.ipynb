# %% [markdown]
# # Simulating Brain models

# %%
import numpy as np
import pandas as pd
import scipy.sparse as sparse
import matplotlib.pyplot as plt
from tqdm import tqdm
from time import time
from scipy.fft import fft
from copy import deepcopy
import networkx as nx

from CriticalBrain import *

# %% [markdown]
# We have to simulate the following cellular automata:
# - I -> A with probability $r_1=10^{-3}$ or if $\sum_{j,active}W_{ij}>T$;
# - A -> R always;
# - R -> I with small probability $r_2=0.2$
#
# We further identify the states with a number:
# - A = $1$
# - I = $0$
# - R = $-1$

# %% [markdown]
# ## Generate the system
#
# We create a system of size $size$, all in the inactive state but for $n_a$ neurons

# %%
states = {0: 'Inactive', 1:'Active', -1: 'Refractory'}

size = int(1e3)
n_a = 10
system = np.zeros(size, dtype=int)

random_active = np.random.randint(0, size, n_a)
system[random_active] += 1

# %% [markdown]
# ## Generate connectivity matrix

# %%
weight_cum_distr =np.loadtxt('data/WCumDistr.csv', delimiter=';')

# %%
plt.plot(weight_cum_distr[:,0], weight_cum_distr[:, 1], 'bo-', label='Cumulative weight distribution')
plt.legend()
#plt.yscale('log')
plt.ylabel('Probability')
plt.xlabel('Weight strenght')
plt.show()

# %%
sample

# %%
height, bins = np.histogram(sample, bins=20, density=True)
h = np.cumsum(height[::-1] )/height.sum()
plt.plot( (bins[:1]+bins[:-1])/2, h[::-1], 'bo-')
plt.yscale('log')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-c1901ce2167c> in <module>
# ----> 1 height, bins = np.histogram(sample, bins=20, density=True)
#       2 h = np.cumsum(height[::-1] )/height.sum()
#       3 plt.plot( (bins[:1]+bins[:-1])/2, h[::-1], 'bo-')
#       4 plt.yscale('log')
#
# NameError: name 'sample' is not defined

# %%
#matrix = sparse.random(int(size), int(size), density=0.1,data_rvs=randint) 
#matrix = sparse.csr_matrix(matrix)

# %%
# ?nx.barabasi_albert_graph

# %%
n = 1000 
m = 8
seed = 999
G = nx.barabasi_albert_graph(n, m, seed)
for n1, n2 in G.edges():
    G[n1][n2]['weight'] = sample_from(weight_cum_distr, 1)[0]
matrix = nx.adjacency_matrix(G)
print(f'Density: {G.number_of_edges()/G.number_of_nodes()**2}')
# Out:
# Density: 0.007936

# %%
deg = [d for n, d in G.degree()]
h, p = np.histogram(deg, bins=500)
plt.loglog()
plt.plot((p[1:]+p[:-1])/2, h, 'o')
#plt.plot( 2e3*np.arange(1, 20).astype(float)**(-2.5)  )
plt.show()

# %%
sorted_mat = np.sort(matrix.todense(), axis=0 )
fig, ax = plt.subplots(figsize=(12,12) )
ax.matshow(sorted_mat[::-1])
plt.show()

# %% [markdown]
# ## Algorithm

# %%
def GH(sys, Adj, T, nsteps=300, r1=1e-3, r2=0.2, time_save = False):
    """
        Parameters:
            sys    (np array)          : system of neurons
            T      (float)             : Threshold
            Adj    (csr sparse matrix) : Weighted Adjacency matrix 
            nsteps (int)               : number of iterations of the algorithm
            r1     (float)             : probability I->A
            r2     (float)             : probability R->I
        
        Returns:
            evol   (np array)          : evolution of [nR, nI, nA] over the simulation
            sys    (np array)          : final configuration of the system
    """
    
    N = len(sys)
    evol = np.array([0, 0, 0])
    if time_save: log = sys.reshape(N, 1)
    for step in tqdm(range(nsteps)):
        # Prepare update R -> I
        R = np.where( sys == -1 )[0]
        nR = R.size
        if nR > 0:
            RtoI = ( np.random.uniform(0, 1, nR) < r2 )
            RtoI = R[ RtoI]
        else:
            RtoI = []
        # Prepare update A -> R
        AtoR = np.where( sys == 1 )[0]
        nA = AtoR.size
        # Prepare update I -> A
        I =  np.where( sys == 0 )[0]
        nI = I.size
        ItoA = ( np.random.uniform(0, 1, nI) < r1 )
        nbr = Adj[ I[:, np.newaxis], AtoR ]         
        strength = np.array([ a[:, a.nonzero()[1] ].sum() for i, a in enumerate(nbr)])
        ItoA = np.logical_or( ItoA, strength > T )
        ItoA = I[ ItoA]
        
        # Updates
        sys[ RtoI ] += 1
        sys[ AtoR ] -= 2
        sys[ ItoA ] += 1
        evol = np.vstack( ( evol, [nR, nI, nA] ) )
        if time_save: log = np.hstack( ( log, sys.reshape(N,1) ) )
    evol = np.delete(evol, 0, axis=0)
    
    if time_save:
        return sys, evol/sys.size, log
    else:
        return sys, evol/sys.size

# %%
system = np.zeros(size, dtype=int)
random_active = np.random.randint(0, size, n_a)
system[random_active] += 1

system, evol = GH(system, matrix, 0.1)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 300/300 [00:21<00:00, 13.92it/s]

# %%
fig, ax = plt.subplots(1, 3, figsize=(14, 6))

ax[0].plot(evol[:, 0], label='Refractory', color='red')
ax[0].plot(evol[:, 1], label='Inactive', color='black')
ax[0].plot(evol[:, 2], label='Active', color='blue')
ax[0].set_xlim(0, 150)
ax[0].legend()

ax[1].plot(evol[:, 2], label='Active', color='blue')
ax[1].set_xlim(50, 150)
ax[1].set_ylim(np.min(evol[50:, 2])-np.min(evol[50:, 2])/10, np.max(evol[50:, 2])+ np.max(evol[50:, 2])/10 )
ax[1].legend()
ax[1].grid()

yf = fft(evol[50:,1])
ax[2].plot( np.abs(yf), color='blue', label='Active freq')
ax[2].set_ylim(0, np.max(np.abs(yf)[1:])+np.max(np.abs(yf)[1:])/10 )
ax[2].set_xlim(0, 150)
ax[2].grid()
ax[2].legend()

plt.show()

# %% [markdown]
# ## Metrics
#
# We will use the following metrics to analyze the results:
# - Lifetime of sustained activity $\tau$. It is defined as the number of of simulation steps after whoch the activity stops, with $r_1=0$.
# - Mean and standard deviation of activity fluctuation:
# $$
# \begin{align*}
# <A>(t) &= \frac{1}{N}\sum_{i=1}^{N} \delta(s_i(t),1) \\
# <A> &= \frac{1}{M}\sum_{i=1}^{M}<A>(t)\\
# \sigma(A)& = \sqrt{ \frac{1}{M}\sum_{i=1}^{M}(<A>(t)-<A>)^2}
# \end{align*}
# $$
# - the size of the second largest cluster $S_2$ of active spins.
# - The correlation. Notice that to obtain a continous signal we take the convolution with a hemodynamic response function
# $$
# h(t)=\frac{1}{k\tau_h(k-1)!}\left(\frac{t}{\tau_h}\right)^k e^{-t/ \tau_h}
# $$

# %%
from math import factorial

def hemod(t, k=3, tau=30):
    p1 = 1/(k*tau*factorial(k-1))
    p2 = (t/tau)**k
    p3 = np.exp(-t/tau)
    return p1*p2*p3

def specs_mat(mat):
    """ Get average and std of matrix mat"""
    N = mat.shape[0]
    
    selfMat = np.diagonal(mat)
    avg = 2/(N*(N-1))*(np.sum(mat-selfMat) )
    std = np.sqrt( 2/(N*(N-1))*( np.sum( (mat-avg)**2 )  - np.sum( (selfMat-avg)**2 ) ) )
    return avg, std

def Correlation(N, Nsteps, evol):
    """
     N: size of the system
     Nsteps: number of time steps
     evol: evolution of the system. Each column is a time step
    """
    hemo_funct = hemod(Nsteps)
    conv = np.array([np.convolve( hemo_funct, evol[s,:]) for s in range(N) ])
    avg = np.mean(conv, axis=1)
    stds = np.std(conv, axis=1)

    Cij = np.zeros( (N, N) )
    for i in range(N):
        for j in range(N):
            Cij[i, j] = np.mean( conv[i]*avg[i]*conv[j]*avg[j]) / stds[i]*stds[j]

    avg_Cij, std_Cij = specs_mat(Cij)
    
    return Cij, avg_Cij, std_Cij

def linear_corr(Wij, Cij):
    """ Linear correlation between the matrices Wij and Cij"""
    N = Wij.shape[0]
    
    avgW, stdW = specs_mat(Wij)
    avgC, stdC = specs_mat(Cij)
    
    coef = 2/(N*(N-1)*stdW*stdC)
    corr = coef*np.sum( (Wij-avgW-np.diagonal(Wij))*(Cij-avgC-np.diagonal(Cij)) )
    return corr

def binary_linear_corr(Wij, Cij, th=4e-11):
    """ Linear correlation between the binarized matrices Wij Cij"""
    W1 = np.sign(Wij)
    th = Cij.mean()
    Cij[ Cij < th]  = 0
    Cij[ Cij >= th] = 1
    
    corr = linear_corr(W1, Cij)
    return corr
    
def susceptibility( N, nsteps, evol):
    """
     N: size of the system
     evol: evolution of the system. Each column is a time step
    """
    #sys = np.zeros( N)
    #mask = np.random.choice([0, 1], size=N, p=[0.4, 0.6]).astype(np.bool)
    #sys[mask] += 1
    hemo = hemod(nsteps)
    
    conv = np.array([np.convolve(hemo, evol[i, :]) for i in range(N) ])
    mean_response = np.mean( conv, axis=0)
    std_response = np.array([ np.std( mean_response[max(0, i-20):min(nsteps, i+20)] ) for i in range(nsteps)])
    susc = ( std_response < 1e-3 ).nonzero()[0][0]
    return susc

def interevent( N, evol):
    """
     N: size of the system
     evol: evolution of the system. Each column is a time step
    """
    nsteps = evol.shape[1]
    act_time = np.array( [ (evol[i, :]==1).nonzero()[0] for i in range(N) ], dtype=object ) 
    inter_ev = np.array([ (act_time[i][1:]-act_time[i][:-1]).mean() if len(act_time[i])>1
                         else 300
                         for i in range(N) ] )
    return inter_ev.mean()

# %%
# Test for the susceptibility
susc_avg = []
susc_std = []
thrs = np.linspace(0.05, 0.2, 20)
nsteps = 100
n_avg = 20
for t in thrs:
    susc = []
    for i in range(n_avg):
        system = np.zeros(size, dtype=int)
        mask = np.random.choice([0, 1], size=size, p=[0.4, 0.6]).astype(np.bool)
        system[mask] += 1
        _, _, evol = GH(system, matrix, 0.1, nsteps=nsteps, time_save=True)
        susc.append( susceptibility(size, nsteps, evol))
    susc_avg.append( np.mean(susc) )
    susc_std.append( np.std(susc) )
# Out:
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:20<00:00,  4.81it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-100-b91be3ad6e66> in <module>
#      12         system[mask] += 1
#      13         _, _, evol = GH(system, matrix, 0.1, nsteps=nsteps, time_save=True)
# ---> 14         susc.append( susceptibility(size, nsteps, evol))
#      15     susc_avg.append( np.mean(susc) )
#      16     susc_std.append( np.std(susc) )
#
# <ipython-input-98-77e6c70ef56b> in susceptibility(N, nsteps, evol)
#      70     mean_response = np.mean( conv, axis=0)
#      71     std_response = np.array([ np.std( mean_response[max(0, i-20):min(nsteps, i+20)] ) for i in range(nsteps)])
# ---> 72     susc = ( std_response < 1e-3 ).nonzero()[0][0]
#      73     return susc
#      74
#
# ...

# %%
susc_avg = np.array(susc_avg)
susc_std = np.array(susc_std)
plt.plot(thrs[:18], susc_avg, 'o--', label='average')
plt.fill_between(thrs[:18], susc_avg+susc_std, susc_avg-susc_std, color='green', alpha=0.4, label='error')
plt.legend()
plt.xlabel('Threshold')
plt.ylabel('Susceptibility')
plt.show()

# %% [markdown]
# ## Putting all together: Brain_simulation

# %%
class BrainSim():
    def __init__(self, N, Na, Adj=None, check_corr=False):
        self.N  = int(N)
        self.Na = int(Na)
        
        # System initialization
        self.in_sys = np.zeros(self.N, dtype=int)
        random_active = np.random.randint(0, self.N, self.Na)
        self.in_sys[random_active] += 1
        self.cur_sys = self.in_sys
        self.check_corr = check_corr
        
        # Adj initialization
        if Adj==None:
            self.Adj = sparse.random(int(self.N), int(self.N), density=0.1, 
                           data_rvs=randint) 
            self.Adj = sparse.csr_matrix(self.Adj)
        else:
            self.Adj = Adj
            
    def randint(size=None, random_state=None):
        """Function to initialize adj matrix"""
        return np.random.uniform(0, 1, size)
    
    def GH(self, T, nsteps=300, r1=1e-3, r2=0.2, time_save = False):
        """
            Parameters:
                T      (float)             : Threshold
                nsteps (int)               : number of iterations of the algorithm
                r1     (float)             : probability I->A
                r2     (float)             : probability R->I

            Returns:
                evol   (np array)          : evolution of [nR, nI, nA] over the simulation
                sys    (np array)          : final configuration of the system
        """
        self.cur_sys = deepcopy(self.in_sys)
        evol = np.array([0, 0, 0])
        if time_save: self.log = self.cur_sys.reshape(self.N, 1)
        for step in range(nsteps):
            # Prepare update R -> I
            R = np.where( self.cur_sys == -1 )[0]
            nR = R.size
            if nR > 0:
                RtoI = ( np.random.uniform(0, 1, nR) < r2 )
                RtoI = R[ RtoI]
            else:
                RtoI = []
            # Prepare update A -> R
            AtoR = np.where( self.cur_sys == 1 )[0]
            nA = AtoR.size
            # Prepare update I -> A
            I =  np.where( self.cur_sys == 0 )[0]
            nI = I.size
            ItoA = ( np.random.uniform(0, 1, nI) < r1 )
            nbr = self.Adj[ I[:, np.newaxis], AtoR ]         
            strength = np.array([ a[:, a.nonzero()[1] ].sum() for i, a in enumerate(nbr)])
            ItoA = np.logical_or( ItoA, strength > T )
            ItoA = I[ ItoA]

            # Updates
            self.cur_sys[ RtoI ] += 1
            self.cur_sys[ AtoR ] -= 2
            self.cur_sys[ ItoA ] += 1
            
            evol = np.vstack( ( evol, [nR, nI, nA] ) )
            if time_save: self.log = np.hstack( (self.log, self.cur_sys.reshape(self.N,1)) )
        evol = np.delete(evol, 0, axis=0)

        return  evol/self.N
    
    def tau(self, activation, nsteps):
        t =  np.where(activation < 1e-4)[0]
        if t.size==0:
            t = nsteps
        else:
            t= np.min(t)
        return t
    
    def Cl_sizes(self):
        A = np.where(self.cur_sys==1)[0]
        nbr = self.Adj[ A[:, np.newaxis], A ].todense()   
        graph = nx.from_numpy_matrix(nbr)
        cl_size = [len(c) for c in sorted(nx.connected_components(graph), key=len, reverse=True)]
        return (cl_size + [0]*2)[:2]
    
    def average(self, T, n_avg=10, nsteps=300, r1=1e-3, r2=0.2):
        avg_evol = self.GH(T, nsteps=nsteps, r1=r1, r2=r2, time_save=True)
        avg_evol = avg_evol[:, 2]
        # Lifetime
        avg_tau = np.array( [self.tau(avg_evol, nsteps) ] )
        # Cluster size
        avg_cl = np.array( self.Cl_sizes() )
        # Correlation matrix
        if self.check_corr:
            Cij, avgCij, stdCij = Correlation(self.N, nsteps, self.log)
            avg_lin_cor = np.array( [linear_corr(self.Adj.todense(), Cij)] )
            avg_bin_cor = np.array( [binary_linear_corr(self.Adj.todense(), Cij)] )
            avg_avgCij = np.array( [avgCij] )
            avg_stdCij = np.array( [stdCij] )
        #print(avg_lin_cor)
        #print(avg_bin_cor)
        # Interevent time
        avg_interv = np.array( interevent( self.N, self.log) )
        
        for i in range(n_avg-1):
            evol = self.GH(T, nsteps=nsteps, r1=r1, r2=r2, time_save=True)
            avg_evol = np.vstack( (avg_evol, evol[:,2] ) )
            # temp variables
            tau_temp = np.array( [self.tau(evol[:, 2], nsteps) ] )
            cl_temp = np.array( self.Cl_sizes() )
            if self.check_corr:
                Cij, avgCij, stdCij = Correlation(self.N, nsteps, self.log)
                lin_cor_temp = np.array( [linear_corr(self.Adj.todense(), Cij)] )
                bin_cor_temp = np.array( [binary_linear_corr(self.Adj.todense(), Cij)] )
            # Average variables
            avg_tau = np.vstack((avg_tau, tau_temp))
            avg_cl = np.vstack( ( avg_cl, cl_temp) )
            if self.check_corr:
                avg_lin_cor = np.vstack( (avg_lin_cor, lin_cor_temp ))
                avg_bin_cor = np.vstack( (avg_bin_cor, bin_cor_temp ) )
                avg_avgCij = np.vstack( (avg_avgCij ,np.array( [avgCij] ) ) )
                avg_stdCij = np.vstack( (avg_stdCij ,np.array( [stdCij] ) ) )
            avg_interv = np.vstack( (avg_interv, np.array( interevent( self.N, self.log)) ) )
                                   
        # stats is vector of shape (1, 16)
        if self.check_corr:
            stats = np.hstack( (avg_tau.mean(), avg_tau.std(), 
                                avg_cl.mean(axis=0), avg_cl.std(axis=0), # Here there are 4 elements
                                avg_avgCij.mean(), avg_avgCij.std(),
                                avg_stdCij.mean(), avg_stdCij.std(),
                                avg_lin_cor.mean(), avg_lin_cor.std(),
                                avg_bin_cor.mean(), avg_bin_cor.std(), 
                                avg_interv.mean(), avg_interv.std()
                                ) )
        else: 
            stats = np.hstack( (avg_tau.mean(), avg_tau.std(), 
                                avg_cl.mean(axis=0), avg_cl.std(axis=0), # Here there are 4 elements
                                avg_interv.mean(), avg_interv.std()
                                ) )
        return np.hstack( ( avg_evol.mean(axis=0), avg_evol.std(axis=0) ) ), stats
    
    def experiment(self, Ts, n_avg=10, nsteps=300, r1=1e-3, r2=0.2):
        self.thresh = Ts
        self.total_evol = np.zeros( nsteps).reshape(nsteps, 1)
        if self.check_corr:
            self.total_stats = np.zeros(16)
        else:
            self.total_stats = np.zeros(8)
        for i, T in tqdm(enumerate(Ts)):
            evol, stats = self.average(T, n_avg=n_avg, nsteps=nsteps, r1=r1, r2=r2)
            self.total_evol = np.hstack( (self.total_evol, evol.reshape(nsteps, 2)) )
            self.total_stats= np.vstack( (self.total_stats, stats))
        self.total_evol = np.delete(self.total_evol, 0, axis=1)
        self.total_stats = np.delete(self.total_stats, 0, axis=0)
        
        return self.total_evol, self.total_stats
    
    def save_evol(self, filename):
        np.save('filename', self.total_evol)
        
    def save_stats(self, filename):
        if self.check_corr:
            columns = ['Threshold', 'tau', 'tau_err', 'Cl1', 'Cl2', 'Cl1_err', 'Cl2_err', 'AvgCor', 'AvgCor_err', 
                       'StdCor', 'StdCor_err', 'LinCor', 'LinCor_err', 'BinCor', 'BinCor_err', 'Interevent', 'Intervent_err']
        else:
            columns = ['Threshold', 'tau', 'tau_err', 'Cl1', 'Cl2', 'Cl1_err', 'Cl2_err',  
                        'Interevent', 'Intervent_err']
        
        final = np.hstack( (np.array(self.thresh).reshape(len(self.thresh), 1), self.total_stats) )
        dataframe = pd.DataFrame( final, columns=columns)
        dataframe.to_csv(filename)

# %%
simulation = BrainSim(1e3, 1e1, Adj=matrix )

# %%
thresholds = np.linspace(0.6, 1.3, 20)

evolutions, statistics = simulation.experiment( thresholds, n_avg=20, nsteps=200)
# Out:
# 20it [5:30:03, 990.15s/it]

# %%
#statistics = pd.read_csv('stats16-01)')
#statistics.head()
# Out:
#    Unnamed: 0  Threshold     tau   tau_err     Cl1   Cl2    Cl1_err   Cl2_err  \
# 0           0   0.050000  300.00   0.00000  100.30  2.75  21.986587  0.993730
# 1           1   0.057895  300.00   0.00000  103.85  2.55  20.768426  1.160819
# 2           2   0.065789  300.00   0.00000   91.35  2.60  19.290607  0.860233
# 3           3   0.073684  285.35  63.85787   90.60  2.95  21.261232  1.564449
# 4           4   0.081579  300.00   0.00000   89.25  3.45  19.266227  1.935846
#
#          AvgCor    AvgCor_err        StdCor    StdCor_err    LinCor  \
# 0 -2.479690e-13  1.003659e-15  4.468935e-13  2.631630e-15 -8.576851
# 1 -2.390358e-13  5.713499e-16  4.282165e-13  1.468935e-15 -8.602049
# 2 -2.283934e-13  7.288452e-16  4.064664e-13  1.602154e-15 -8.599912
# 3 -2.162394e-13  1.425134e-15  3.820964e-13  2.667461e-15 -8.608372
# 4 -2.019254e-13  8.846614e-16  3.534519e-13  1.897342e-15 -8.617535
#
#    LinCor_err    BinCor  BinCor_err  Interevent  Intervent_err
# ...

# %%
#statistics = pd.read_csv('stats16-01)')
#statistics = statistics.drop(['Unnamed: 0', 'Threshold'], axis=1)
#statistics = statistics.to_numpy()

# %%
fig, ax = plt.subplots(2, 2, figsize=(15, 12))

ax = ax.flatten()
i=0
ax[i].plot( thresholds, statistics[:,i], 'o--', color='blue', label='Average')
temp_plus = [ min(300, statistics[j, i]+statistics[j, i+1]) for j in range(20)]
temp_minu = [ max(0, statistics[j, i]-statistics[j, i+1]) for j in range(20)]
ax[i].fill_between( thresholds, temp_plus, temp_minu,
                color='green', alpha=0.5, label='Standard deviation')
ax[i].set_xlabel('Threshold T')
ax[i].set_ylabel('Lifetime of sustained activity $\\tau$')
ax[i].legend()

for i in range(2, 4):
    plus = [ min(300, statistics[j, i]+statistics[j, i+2]) for j in range(20)]
    minus = [ max(0, statistics[j, i]-statistics[j, i+2]) for j in range(20)]
    ax[i-1].plot( thresholds, statistics[:,i], 'o--', color='blue', label='Average')
    ax[i-1].fill_between( thresholds, plus, minus,
                       color='green', alpha=0.5, label='Standard deviation')
    ax[i-1].set_xlabel('Threshold T')
    ax[i-1].legend()
ax[1].set_ylabel('Largest cluster size $C_1$')
ax[2].set_ylabel('Second largest cluster size $C_2$')

i = 6

plus = [ min(300, statistics[j, i]+statistics[j, i+1]) for j in range(20)]
minus = [ max(0, statistics[j, i]-statistics[j, i+1]) for j in range(20)]

ax[3].plot( thresholds, statistics[:,i], 'o--', color='blue', label='Average')
ax[3].fill_between( thresholds, plus, minus,
                   color='green', alpha=0.5, label='Standard deviation')
ax[3].set_xlabel('Threshold T')
ax[3].set_ylabel('Interevent time $\\Delta t$')
ax[3].legend()

#plt.savefig('normal.pdf')
plt.show()

# %%
evolutions.shape
# Out:
# (300, 40)

# %%
fig, ax = plt.subplots(5, 4, figsize=(15,20))
ax = ax.flatten()
for i in range(0, 40, 2):
    ax[i//2].plot(evolutions[:, i])
    ax[i//2].fill_between( np.arange(300), evolutions[:, i]+evolutions[:, i+1], evolutions[:, i]-evolutions[:, i+1],
                   color='green', alpha=0.5, label='Standard deviation')
    ax[i//2].set_title('Threshold = %.2f' %(thresholds[i//2]) )
    ax[i//2].set_xlim(50, 250)
    ax[i//2].set_ylim(0, np.max(evolutions[:, i]))

# %%
act_means = np.mean(evolutions, axis=0)
mask = [ i%2==0 for i in range(40) ]
plt.plot(thresholds, act_means[mask], label='Average')
plt.fill_between( thresholds, act_means[mask]+act_means[np.logical_not(mask)], 
                 act_means[mask]-act_means[np.logical_not(mask)],
                   color='green', alpha=0.5, label='Standard deviation')
plt.legend()
plt.ylabel('Activity')
plt.xlabel('Threshold')
plt.savefig('Activity.pdf')

# %%
fig, ax = plt.subplots(2, 2, figsize=(15, 16))
j = 0 
ax = ax.flatten()
columns = ['tau', 'tau_err', 'Cl1', 'Cl2', 'Cl1_err', 'Cl2_err', 'AvgCor', 'AvgCor_err', 
                   'StdCor', 'StdCor_err', 'LinCor', 'LinCor_err', 'BinCor', 'BinCor_err', 'Interevent', 'Intervent_err']

for i in range(6, 14, 2):
    ax[j].plot( thresholds, statistics[:,i], 'o--', color='blue', label='Average')
    ax[j].fill_between( thresholds, statistics[:, i]+statistics[:, i+1], statistics[:, i]-statistics[:, i+1],
                       color='green', alpha=0.5, label='Standard deviation')
    ax[j].set_xlabel('Threshold T')
    ax[j].set_title(columns[i])
    ax[j].legend()
    
    j += 1
plt.show()

# %%
#simulation.save_stats('stats16-01)')

# %% [markdown]
# # Simulating attacks at criticality
# remove nodes by:
# - largest degree
# - largest connectivity
# - largest betweeness centrality
# - largest eigenvector centrality
# - largest partecipation coefficient
# - chosen at random
#
# remove links by:
# - largest betweenness centrality
# - links with heavyiest weight
# - chosen at random

# %%
def attack_node(graph, metric, nsteps=50):
    """
        Remove @nsteps nodes with highest @metric from @graph
    """
    graph = graph.copy()
    nodes = np.array( [n for n in graph.nodes()] )
    sorting = np.argsort(metric)[::-1]
    sorted_nodes = nodes[sorting]
    for i in range(nsteps):
        graph.remove_node( sorted_nodes[i] )

    return graph

def attack_link(graph, metric, nsteps=50):
    """
        Remove @nsteps edges with highest @metric from @graph
    """
    graph = graph.copy()
    edges = np.array( [e for e in graph.edges()] )
    sorting = np.argsort(metric)[::-1]
    sorted_edges = edges[sorting]
    for i in range(nsteps):
        graph.remove_edge( sorted_edges[i][0], sorted_edges[i][1] )

    return graph

# %%
# Critical threshold
Tc = [0.12]

# %%
# Nodes metrics
degree = np.array([ d for n, d in G.degree()] )
betw_centr = np.array( list(nx.betweenness_centrality(G).values()) )
eigv_centr = np.array( list(nx.eigenvector_centrality_numpy(G).values()) )

random = np.random.uniform(0,1, G.number_of_nodes())

# %%
# Links metrics
weights = np.array([ w for _, _, w in G.edges.data('weight')] )
random_edg = np.random.uniform(0,1, G.number_of_edges())

# %% [markdown]
# ### Make experiments between 0.08-0.18

# %%
log_stats = {}
keys = ['degree', 'betweeness', 'eigenvector', 'random']
metrics = [degree, betw_centr, eigv_centr, random]
thresholds = np.linspace(0.05, 0.18, 10)
nsteps = 50
for i, met in enumerate(metrics):
    damaged_graph = attack_node(G, met, nsteps=nsteps)
    new_adj = nx.adjacency_matrix( damaged_graph)

    damaged_simulation = BrainSim(1e3-nsteps, 1e1, Adj=new_adj )
    
    evolutions, statistics = damaged_simulation.experiment( thresholds, n_avg=10, nsteps=300)
    
    log_stats[keys[i]] = statistics
# Out:
# 10it [1:39:01, 594.14s/it]
# 10it [1:58:18, 709.87s/it]
# 10it [1:36:09, 576.97s/it]
# 10it [1:20:22, 482.23s/it]

# %%
fig, ax = plt.subplots(2, 2, figsize=(15, 12))
color_line = ['blue', 'red', 'black', 'green']
color_std = ['cyan', 'lightcoral', 'gainsboro', 'lime']


ax = ax.flatten()
i=0
for k in range(4): 
    ax[i].plot( thresholds,  log_stats[keys[k]][:, i], 'o--', color=color_line[k], label=keys[k])
    temp_plus = [ min(300, log_stats[keys[k]][j, i]+log_stats[keys[k]][j, i+1]) for j in range(len(thresholds))]
    temp_minu = [ max(0, log_stats[keys[k]][j, i]-log_stats[keys[k]][j, i+1]) for j in range(len(thresholds))]
    ax[i].fill_between( thresholds, temp_plus, temp_minu,
                    color=color_std[k], alpha=0.5)
ax[i].set_xlabel('Threshold T')
ax[i].set_ylabel('Lifetime of sustained activity $\\tau$')
ax[i].legend()

for i in range(2, 4):
    for k in range(4):
        plus = [ min(300, log_stats[keys[k]][j, i]+log_stats[keys[k]][j, i+2]) for j in range(len(thresholds))]
        minus = [ max(0, log_stats[keys[k]][j, i]-log_stats[keys[k]][j, i+2]) for j in range(len(thresholds))]
        
        ax[i-1].plot( thresholds,  log_stats[keys[k]][:, i], 'o--',  color=color_line[k], label=keys[k])
        ax[i-1].fill_between( thresholds, plus, minus,
                           color=color_std[k], alpha=0.5)
    ax[i-1].set_xlabel('Threshold T')
    ax[i-1].legend()
ax[1].set_ylabel('Largest cluster size $C_1$')
ax[2].set_ylabel('Second largest cluster size $C_2$')

i = 6
for k in range(4):
    plus = [ min(300, log_stats[keys[k]][j, i]+log_stats[keys[k]][j, i+1]) for j in range(len(thresholds))]
    minus = [ max(0, log_stats[keys[k]][j, i]-log_stats[keys[k]][j, i+1]) for j in range(len(thresholds))]
    
    ax[3].plot( thresholds, log_stats[keys[k]][:, i], 'o--',  color=color_line[k], label=keys[k])
    ax[3].fill_between( thresholds, plus, minus,
                        color=color_std[k], alpha=0.5)
ax[3].set_xlabel('Threshold T')
ax[3].set_ylabel('Interevent time $\\Delta t$')
ax[3].legend()

#plt.show()
#plt.savefig('damage.pdf')

# %%
evolutions.shape
# Out:
# (300, 40)
